# %%
import os 
train_file ="train.csv"
val_file ="val.csv"
root_dir="/content/gdrive/MyDrive/chexpert/CheXpert-v1.0-small"

# %%
# Data Cleaning 

# Sumedh Please check for test cases here
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)

#train_df=pd.read_csv(os.path.join(root_dir,train_file))
#train_df.head()
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/MyDrive/chexpert/
# Out:
# /content/gdrive/MyDrive/chexpert

# %%
# !unzip CheXpert-v1.0-small.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/patient60445/study2/view1_frontal.jpg
#   inflating: train/patient60445/study2/view2_lateral.jpg
#   inflating: train/patient60446/study1/view1_frontal.jpg
#   inflating: train/patient60446/study2/view1_frontal.jpg
#   inflating: train/patient60446/study2/view2_lateral.jpg
#   inflating: train/patient60447/study1/view1_frontal.jpg
#   inflating: train/patient60447/study1/view2_lateral.jpg
#   inflating: train/patient60448/study1/view1_frontal.jpg
#   inflating: train/patient60448/study1/view2_lateral.jpg
#   inflating: train/patient60448/study1/view3_lateral.jpg
#   inflating: train/patient60449/study1/view1_frontal.jpg
#   inflating: train/patient60449/study1/view2_lateral.jpg
#   inflating: train/patient60450/study1/view1_frontal.jpg
#   inflating: train/patient60450/study1/view2_lateral.jpg
#   inflating: train/patient60451/study1/view1_frontal.jpg
#   inflating: train/patient60451/study1/view2_lateral.jpg
#   inflating: train/patient60452/study1/view1_frontal.jpg
#   inflating: train/patient60452/study1/view2_lateral.jpg
#   inflating: train/patient60452/study1/view3_lateral.jpg
#   inflating: train/patient60453/study1/view1_frontal.jpg
#   inflating: train/patient60453/study1/view2_frontal.jpg
#   inflating: train/patient60454/study1/view1_frontal.jpg
#   inflating: train/patient60455/study1/view1_frontal.jpg
#   inflating: train/patient60455/study2/view1_frontal.jpg
#   inflating: train/patient60456/study1/view1_frontal.jpg
#   inflating: train/patient60456/study1/view2_lateral.jpg
#   inflating: train/patient60457/study1/view1_frontal.jpg
#   inflating: train/patient60457/study1/view2_lateral.jpg
#   inflating: train/patient60458/study1/view1_frontal.jpg
#   inflating: train/patient60458/study1/view2_lateral.jpg
#   inflating: train/patient60458/study2/view1_frontal.jpg
#   inflating: train/patient60459/study1/view1_frontal.jpg
#   inflating: train/patient60459/study1/view2_frontal.jpg
#   inflating: train/patient60460/study1/view1_frontal.jpg
#   inflating: train/patient60460/study1/view2_frontal.jpg
#   inflating: train/patient60460/study1/view3_lateral.jpg
#   inflating: train/patient60461/study1/view1_frontal.jpg
#   inflating: train/patient60461/study1/view2_frontal.jpg
#   inflating: train/patient60462/study1/view1_frontal.jpg
#   inflating: train/patient60462/study1/view2_lateral.jpg
#   inflating: train/patient60463/study1/view1_frontal.jpg
#   inflating: train/patient60464/study1/view1_frontal.jpg
#   inflating: train/patient60464/study1/view2_lateral.jpg
#   inflating: train/patient60465/study1/view1_frontal.jpg
#   inflating: train/patient60465/study1/view2_lateral.jpg
#   inflating: train/patient60466/study1/view1_frontal.jpg
#   inflating: train/patient60466/study1/view2_frontal.jpg
#   inflating: train/patient60467/study1/view1_frontal.jpg
#   inflating: train/patient60467/study1/view2_lateral.jpg
#   inflating: train/patient60468/study1/view1_frontal.jpg
#   inflating: train/patient60468/study1/view2_lateral.jpg
#   inflating: train/patient60469/study1/view1_frontal.jpg
#   inflating: train/patient60470/study1/view1_frontal.jpg
#   inflating: train/patient60471/study1/view1_frontal.jpg
#   inflating: train/patient60471/study1/view2_lateral.jpg
#   inflating: train/patient60472/study1/view1_frontal.jpg
#   inflating: train/patient60472/study1/view2_lateral.jpg
#   inflating: train/patient60473/study1/view1_frontal.jpg
#   inflating: train/patient60473/study1/view2_lateral.jpg
#   inflating: train/patient60474/study1/view1_frontal.jpg
#   inflating: train/patient60474/study1/view2_lateral.jpg
#   inflating: train/patient60475/study1/view1_frontal.jpg
#   inflating: train/patient60475/study1/view2_lateral.jpg
#   inflating: train/patient60476/study1/view1_frontal.jpg
#   inflating: train/patient60477/study1/view1_frontal.jpg
#   inflating: train/patient60477/study1/view2_lateral.jpg
#   inflating: train/patient60477/study1/view3_lateral.jpg
#   inflating: train/patient60478/study1/view1_frontal.jpg
#   inflating: train/patient60478/study1/view2_lateral.jpg
#   inflating: train/patient60479/study1/view1_frontal.jpg
#   inflating: train/patient60479/study1/view2_lateral.jpg
#   inflating: train/patient60480/study1/view1_frontal.jpg
#   inflating: train/patient60480/study1/view2_frontal.jpg
#   inflating: train/patient60480/study2/view1_frontal.jpg
#   inflating: train/patient60480/study2/view2_frontal.jpg
#   inflating: train/patient60480/study3/view1_frontal.jpg
#   inflating: train/patient60481/study1/view1_frontal.jpg
#   inflating: train/patient60481/study1/view2_frontal.jpg
#   inflating: train/patient60482/study1/view1_frontal.jpg
#   inflating: train/patient60482/study1/view2_frontal.jpg
#   inflating: train/patient60483/study1/view1_frontal.jpg
#   inflating: train/patient60483/study2/view1_frontal.jpg
#   inflating: train/patient60484/study1/view1_frontal.jpg
#   inflating: train/patient60484/study1/view2_lateral.jpg
#   inflating: train/patient60485/study1/view1_frontal.jpg
#   inflating: train/patient60485/study1/view2_lateral.jpg
#   inflating: train/patient60486/study1/view1_frontal.jpg
#   inflating: train/patient60487/study1/view1_frontal.jpg
#   inflating: train/patient60487/study1/view2_lateral.jpg
#   inflating: train/patient60488/study1/view1_frontal.jpg
#   inflating: train/patient60488/study1/view2_lateral.jpg
#   inflating: train/patient60489/study1/view1_frontal.jpg
#   inflating: train/patient60489/study2/view1_frontal.jpg
#   inflating: train/patient60489/study2/view2_frontal.jpg
#   inflating: train/patient60490/study1/view1_frontal.jpg
#   inflating: train/patient60490/study2/view1_frontal.jpg
#   inflating: train/patient60490/study2/view2_lateral.jpg
#   inflating: train/patient60491/study1/view1_frontal.jpg
#   inflating: train/patient60491/study1/view2_lateral.jpg
#   inflating: train/patient60491/study2/view1_frontal.jpg
#   inflating: train/patient60491/study3/view1_frontal.jpg
#   inflating: train/patient60492/study1/view1_frontal.jpg
#   inflating: train/patient60492/study1/view2_lateral.jpg
#   inflating: train/patient60493/study1/view1_frontal.jpg
#   inflating: train/patient60493/study1/view2_lateral.jpg
#   inflating: train/patient60494/study1/view1_frontal.jpg
#   inflating: train/patient60494/study1/view2_lateral.jpg
#   inflating: train/patient60494/study1/view3_lateral.jpg
#   inflating: train/patient60495/study1/view1_frontal.jpg
#   inflating: train/patient60495/study2/view1_frontal.jpg
#   inflating: train/patient60495/study2/view2_lateral.jpg
#   inflating: train/patient60495/study2/view3_lateral.jpg
#   inflating: train/patient60496/study1/view1_frontal.jpg
#   inflating: train/patient60496/study1/view2_lateral.jpg
#   inflating: train/patient60497/study1/view1_frontal.jpg
#   inflating: train/patient60498/study1/view1_frontal.jpg
#   inflating: train/patient60498/study1/view2_lateral.jpg
#   inflating: train/patient60499/study1/view1_frontal.jpg
#   inflating: train/patient60499/study1/view2_lateral.jpg
#   inflating: train/patient60500/study1/view1_frontal.jpg
#   inflating: train/patient60500/study1/view2_lateral.jpg
#   inflating: train/patient60501/study1/view1_frontal.jpg
#   inflating: train/patient60501/study1/view2_frontal.jpg
#   inflating: train/patient60502/study1/view1_frontal.jpg
#   inflating: train/patient60502/study1/view2_lateral.jpg
#   inflating: train/patient60502/study2/view1_frontal.jpg
#   inflating: train/patient60503/study1/view1_frontal.jpg
#   inflating: train/patient60503/study1/view2_lateral.jpg
#   inflating: train/patient60504/study1/view1_frontal.jpg
#   inflating: train/patient60505/study1/view1_frontal.jpg
#   inflating: train/patient60505/study1/view2_lateral.jpg
#   inflating: train/patient60506/study1/view1_frontal.jpg
#   inflating: train/patient60506/study1/view2_lateral.jpg
#   inflating: train/patient60507/study1/view1_frontal.jpg
#   inflating: train/patient60507/study1/view2_lateral.jpg
#   inflating: train/patient60508/study1/view1_frontal.jpg
#   inflating: train/patient60508/study1/view2_lateral.jpg
#   inflating: train/patient60509/study1/view1_frontal.jpg
#   inflating: train/patient60509/study1/view2_frontal.jpg
#   inflating: train/patient60509/study2/view1_frontal.jpg
#   inflating: train/patient60510/study1/view1_frontal.jpg
#   inflating: train/patient60510/study1/view2_lateral.jpg
#   inflating: train/patient60511/study1/view1_frontal.jpg
#   inflating: train/patient60511/study1/view2_lateral.jpg
#   inflating: train/patient60512/study1/view1_frontal.jpg
#   inflating: train/patient60512/study2/view1_frontal.jpg
#   inflating: train/patient60512/study2/view2_lateral.jpg
#   inflating: train/patient60513/study1/view1_frontal.jpg
#   inflating: train/patient60514/study1/view1_frontal.jpg
#   inflating: train/patient60514/study1/view2_lateral.jpg
#   inflating: train/patient60515/study1/view1_frontal.jpg
#   inflating: train/patient60515/study1/view2_lateral.jpg
#   inflating: train/patient60516/study1/view1_frontal.jpg
#   inflating: train/patient60516/study1/view2_lateral.jpg
#   inflating: train/patient60517/study1/view1_frontal.jpg
#   inflating: train/patient60517/study1/view2_lateral.jpg
#   inflating: train/patient60518/study1/view1_frontal.jpg
#   inflating: train/patient60518/study1/view2_lateral.jpg
#   inflating: train/patient60519/study1/view1_frontal.jpg
#   inflating: train/patient60519/study1/view2_lateral.jpg
#   inflating: train/patient60520/study1/view1_frontal.jpg
#   inflating: train/patient60520/study1/view2_lateral.jpg
#   inflating: train/patient60521/study1/view1_frontal.jpg
#   inflating: train/patient60521/study1/view2_lateral.jpg
#   inflating: train/patient60521/study1/view3_lateral.jpg
#   inflating: train/patient60522/study1/view1_frontal.jpg
#   inflating: train/patient60522/study1/view2_lateral.jpg
#   inflating: train/patient60523/study1/view1_frontal.jpg
#   inflating: train/patient60523/study1/view2_lateral.jpg
#   inflating: train/patient60524/study1/view1_frontal.jpg
#   inflating: train/patient60524/study2/view1_frontal.jpg
#   inflating: train/patient60524/study2/view2_lateral.jpg
#   inflating: train/patient60525/study1/view1_frontal.jpg
#   inflating: train/patient60525/study1/view2_lateral.jpg
#   inflating: train/patient60526/study1/view1_frontal.jpg
#   inflating: train/patient60526/study2/view1_frontal.jpg
#   inflating: train/patient60526/study2/view2_lateral.jpg
#   inflating: train/patient60526/study3/view1_frontal.jpg
#   inflating: train/patient60527/study1/view1_frontal.jpg
#   inflating: train/patient60527/study1/view2_lateral.jpg
#   inflating: train/patient60528/study1/view1_frontal.jpg
#   inflating: train/patient60528/study1/view2_lateral.jpg
#   inflating: train/patient60529/study1/view1_frontal.jpg
#   inflating: train/patient60529/study1/view2_lateral.jpg
#   inflating: train/patient60530/study1/view1_frontal.jpg
#   inflating: train/patient60530/study1/view2_lateral.jpg
#   inflating: train/patient60531/study1/view1_frontal.jpg
#   inflating: train/patient60532/study1/view1_frontal.jpg
#   inflating: train/patient60532/study1/view2_lateral.jpg
#   inflating: train/patient60533/study1/view1_frontal.jpg
#   inflating: train/patient60533/study1/view2_frontal.jpg
#   inflating: train/patient60534/study1/view1_frontal.jpg
#   inflating: train/patient60534/study2/view1_frontal.jpg
#   inflating: train/patient60534/study2/view2_lateral.jpg
#   inflating: train/patient60534/study3/view1_frontal.jpg
#   inflating: train/patient60534/study4/view1_frontal.jpg
#   inflating: train/patient60535/study1/view1_frontal.jpg
#   inflating: train/patient60535/study1/view2_frontal.jpg
#   inflating: train/patient60536/study1/view1_frontal.jpg
#   inflating: train/patient60536/study1/view2_lateral.jpg
#   inflating: train/patient60537/study1/view1_frontal.jpg
#   inflating: train/patient60537/study1/view2_lateral.jpg
#   inflating: train/patient60538/study1/view1_frontal.jpg
#   inflating: train/patient60539/study1/view1_frontal.jpg
#   inflating: train/patient60539/study1/view2_lateral.jpg
#   inflating: train/patient60540/study1/view1_frontal.jpg
#   inflating: train/patient60540/study1/view2_lateral.jpg
#   inflating: train/patient60540/study2/view1_frontal.jpg
#   inflating: train/patient60540/study3/view1_frontal.jpg
#   inflating: train/patient60541/study1/view1_frontal.jpg
#   inflating: train/patient60542/study1/view1_frontal.jpg
#   inflating: train/patient60542/study1/view2_lateral.jpg
#   inflating: train/patient60543/study1/view1_frontal.jpg
#   inflating: train/patient60543/study1/view2_frontal.jpg
#   inflating: train/patient60544/study1/view1_frontal.jpg
#   inflating: train/patient60544/study1/view2_frontal.jpg
#   inflating: train/patient60545/study1/view1_frontal.jpg
#   inflating: train/patient60546/study1/view1_frontal.jpg
#   inflating: train/patient60546/study1/view2_lateral.jpg
#   inflating: train/patient60547/study1/view1_frontal.jpg
#   inflating: train/patient60547/study1/view2_frontal.jpg
#   inflating: train/patient60548/study1/view1_frontal.jpg
#   inflating: train/patient60548/study1/view2_lateral.jpg
#   inflating: train/patient60548/study1/view3_lateral.jpg
#   inflating: train/patient60549/study1/view1_frontal.jpg
#   inflating: train/patient60549/study2/view1_frontal.jpg
#   inflating: train/patient60549/study2/view2_lateral.jpg
#   inflating: train/patient60550/study1/view1_frontal.jpg
#   inflating: train/patient60551/study1/view1_frontal.jpg
#   inflating: train/patient60551/study1/view2_lateral.jpg
#   inflating: train/patient60551/study2/view1_frontal.jpg
#   inflating: train/patient60552/study1/view1_frontal.jpg
#   inflating: train/patient60552/study1/view2_lateral.jpg
#   inflating: train/patient60553/study1/view1_frontal.jpg
#   inflating: train/patient60553/study2/view1_frontal.jpg
#   inflating: train/patient60553/study2/view2_lateral.jpg
#   inflating: train/patient60554/study1/view1_frontal.jpg
#   inflating: train/patient60555/study1/view1_frontal.jpg
#   inflating: train/patient60556/study1/view1_frontal.jpg
#   inflating: train/patient60557/study1/view1_frontal.jpg
#   inflating: train/patient60558/study1/view1_frontal.jpg
#   inflating: train/patient60558/study1/view2_lateral.jpg
#   inflating: train/patient60559/study1/view1_frontal.jpg
#   inflating: train/patient60559/study1/view2_lateral.jpg
#   inflating: train/patient60560/study1/view1_frontal.jpg
#   inflating: train/patient60560/study1/view2_lateral.jpg
#   inflating: train/patient60561/study1/view1_frontal.jpg
#   inflating: train/patient60561/study1/view2_lateral.jpg
#   inflating: train/patient60562/study1/view1_frontal.jpg
#   inflating: train/patient60562/study1/view2_lateral.jpg
#   inflating: train/patient60563/study1/view1_frontal.jpg
#   inflating: train/patient60563/study1/view2_lateral.jpg
#   inflating: train/patient60564/study1/view1_frontal.jpg
#   inflating: train/patient60564/study1/view2_lateral.jpg
#   inflating: train/patient60565/study1/view1_frontal.jpg
#   inflating: train/patient60565/study1/view2_lateral.jpg
#   inflating: train/patient60566/study1/view1_frontal.jpg
#   inflating: train/patient60566/study1/view2_lateral.jpg
#   inflating: train/patient60567/study1/view1_frontal.jpg
#   inflating: train/patient60567/study2/view1_frontal.jpg
#   inflating: train/patient60567/study2/view2_lateral.jpg
#   inflating: train/patient60568/study1/view1_frontal.jpg
#   inflating: train/patient60569/study1/view1_frontal.jpg
#   inflating: train/patient60570/study1/view1_frontal.jpg
#   inflating: train/patient60570/study1/view2_frontal.jpg
#   inflating: train/patient60571/study1/view1_frontal.jpg
#   inflating: train/patient60571/study2/view1_frontal.jpg
#   inflating: train/patient60571/study2/view2_lateral.jpg
#   inflating: train/patient60572/study1/view1_frontal.jpg
#   inflating: train/patient60572/study1/view2_lateral.jpg
#   inflating: train/patient60573/study1/view1_frontal.jpg
#   inflating: train/patient60574/study1/view1_frontal.jpg
#   inflating: train/patient60575/study1/view1_frontal.jpg
#   inflating: train/patient60575/study1/view2_lateral.jpg
#   inflating: train/patient60576/study1/view1_frontal.jpg
#   inflating: train/patient60577/study1/view1_frontal.jpg
#   inflating: train/patient60577/study1/view2_frontal.jpg
#   inflating: train/patient60578/study1/view1_frontal.jpg
#   inflating: train/patient60578/study1/view2_lateral.jpg
#   inflating: train/patient60579/study1/view1_frontal.jpg
#   inflating: train/patient60579/study1/view2_lateral.jpg
#   inflating: train/patient60579/study1/view3_lateral.jpg
#   inflating: train/patient60580/study1/view1_frontal.jpg
#   inflating: train/patient60580/study1/view2_lateral.jpg
#   inflating: train/patient60581/study1/view1_frontal.jpg
#   inflating: train/patient60581/study1/view2_lateral.jpg
#   inflating: train/patient60582/study1/view1_frontal.jpg
#   inflating: train/patient60583/study1/view1_frontal.jpg
#   inflating: train/patient60583/study1/view2_lateral.jpg
#   inflating: train/patient60584/study1/view1_frontal.jpg
#   inflating: train/patient60584/study1/view2_lateral.jpg
#   inflating: train/patient60585/study1/view1_frontal.jpg
#   inflating: train/patient60585/study1/view2_frontal.jpg
#   inflating: train/patient60585/study1/view3_lateral.jpg
#   inflating: train/patient60586/study1/view1_frontal.jpg
#   inflating: train/patient60586/study1/view2_lateral.jpg
#   inflating: train/patient60587/study1/view1_frontal.jpg
#   inflating: train/patient60587/study1/view2_lateral.jpg
#   inflating: train/patient60588/study1/view1_frontal.jpg
#   inflating: train/patient60588/study1/view2_lateral.jpg
#   inflating: train/patient60589/study1/view1_frontal.jpg
#   inflating: train/patient60589/study1/view2_lateral.jpg
#   inflating: train/patient60590/study1/view1_frontal.jpg
#   inflating: train/patient60590/study1/view2_lateral.jpg
#   inflating: train/patient60591/study1/view1_frontal.jpg
#   inflating: train/patient60591/study1/view2_frontal.jpg
#   inflating: train/patient60592/study1/view1_frontal.jpg
#   inflating: train/patient60592/study1/view2_lateral.jpg
#   inflating: train/patient60593/study1/view1_frontal.jpg
#   inflating: train/patient60593/study1/view2_lateral.jpg
#   inflating: train/patient60594/study1/view1_frontal.jpg
#   inflating: train/patient60595/study1/view1_frontal.jpg
#   inflating: train/patient60595/study1/view2_lateral.jpg
#   inflating: train/patient60596/study1/view1_frontal.jpg
#   inflating: train/patient60596/study1/view2_frontal.jpg
#   inflating: train/patient60596/study1/view3_lateral.jpg
#   inflating: train/patient60597/study1/view1_frontal.jpg
#   inflating: train/patient60597/study1/view2_frontal.jpg
#   inflating: train/patient60598/study1/view1_frontal.jpg
#   inflating: train/patient60598/study1/view2_lateral.jpg
#   inflating: train/patient60599/study1/view1_frontal.jpg
#   inflating: train/patient60599/study1/view2_lateral.jpg
#   inflating: train/patient60600/study1/view1_frontal.jpg
#   inflating: train/patient60600/study1/view2_lateral.jpg
#   inflating: train/patient60601/study1/view1_frontal.jpg
#   inflating: train/patient60601/study1/view2_lateral.jpg
#   inflating: train/patient60602/study1/view1_frontal.jpg
#   inflating: train/patient60603/study1/view1_frontal.jpg
#   inflating: train/patient60603/study2/view1_frontal.jpg
#   inflating: train/patient60603/study3/view1_frontal.jpg
#   inflating: train/patient60604/study1/view1_frontal.jpg
#   inflating: train/patient60604/study1/view2_frontal.jpg
#   inflating: train/patient60605/study1/view1_frontal.jpg
#   inflating: train/patient60605/study1/view2_lateral.jpg
#   inflating: train/patient60605/study1/view3_lateral.jpg
#   inflating: train/patient60606/study1/view1_frontal.jpg
#   inflating: train/patient60606/study1/view2_lateral.jpg
#   inflating: train/patient60607/study1/view1_frontal.jpg
#   inflating: train/patient60607/study1/view2_frontal.jpg
#   inflating: train/patient60608/study1/view1_frontal.jpg
#   inflating: train/patient60608/study1/view2_frontal.jpg
#   inflating: train/patient60609/study1/view1_frontal.jpg
#   inflating: train/patient60609/study1/view2_lateral.jpg
#   inflating: train/patient60610/study1/view1_frontal.jpg
#   inflating: train/patient60610/study1/view2_frontal.jpg
#   inflating: train/patient60611/study1/view1_frontal.jpg
#   inflating: train/patient60611/study1/view2_lateral.jpg
#   inflating: train/patient60612/study1/view1_frontal.jpg
#   inflating: train/patient60613/study1/view1_frontal.jpg
#   inflating: train/patient60613/study1/view2_lateral.jpg
#   inflating: train/patient60614/study1/view1_frontal.jpg
#   inflating: train/patient60614/study1/view2_lateral.jpg
#   inflating: train/patient60615/study1/view1_frontal.jpg
#   inflating: train/patient60615/study1/view2_lateral.jpg
#   inflating: train/patient60616/study1/view1_frontal.jpg
#   inflating: train/patient60616/study1/view2_lateral.jpg
#   inflating: train/patient60617/study1/view1_frontal.jpg
#   inflating: train/patient60618/study1/view1_frontal.jpg
#   inflating: train/patient60618/study1/view2_lateral.jpg
#   inflating: train/patient60619/study1/view1_frontal.jpg
#   inflating: train/patient60620/study1/view1_frontal.jpg
#   inflating: train/patient60620/study1/view2_lateral.jpg
#   inflating: train/patient60621/study1/view1_frontal.jpg
#   inflating: train/patient60621/study2/view1_frontal.jpg
#   inflating: train/patient60622/study1/view1_frontal.jpg
#   inflating: train/patient60622/study1/view2_lateral.jpg
#   inflating: train/patient60623/study1/view1_frontal.jpg
#   inflating: train/patient60623/study1/view2_lateral.jpg
#   inflating: train/patient60624/study1/view1_frontal.jpg
#   inflating: train/patient60624/study1/view2_lateral.jpg
#   inflating: train/patient60625/study1/view1_frontal.jpg
#   inflating: train/patient60625/study1/view2_frontal.jpg
#   inflating: train/patient60626/study1/view1_frontal.jpg
#   inflating: train/patient60626/study1/view2_lateral.jpg
#   inflating: train/patient60627/study1/view1_frontal.jpg
#   inflating: train/patient60627/study1/view2_lateral.jpg
#   inflating: train/patient60628/study1/view1_frontal.jpg
#   inflating: train/patient60628/study1/view2_lateral.jpg
#   inflating: train/patient60629/study1/view1_frontal.jpg
#   inflating: train/patient60629/study1/view2_lateral.jpg
#   inflating: train/patient60630/study1/view1_frontal.jpg
#   inflating: train/patient60630/study2/view1_frontal.jpg
#   inflating: train/patient60630/study3/view1_frontal.jpg
#   inflating: train/patient60631/study1/view1_frontal.jpg
#   inflating: train/patient60631/study1/view2_lateral.jpg
#   inflating: train/patient60632/study1/view1_frontal.jpg
#   inflating: train/patient60632/study1/view2_lateral.jpg
#   inflating: train/patient60632/study1/view3_lateral.jpg
#   inflating: train/patient60633/study1/view1_frontal.jpg
#   inflating: train/patient60634/study1/view1_frontal.jpg
#   inflating: train/patient60634/study1/view2_lateral.jpg
#   inflating: train/patient60635/study1/view1_frontal.jpg
#   inflating: train/patient60635/study2/view1_frontal.jpg
#   inflating: train/patient60635/study2/view2_frontal.jpg
#   inflating: train/patient60636/study1/view1_frontal.jpg
#   inflating: train/patient60636/study1/view2_lateral.jpg
#   inflating: train/patient60636/study2/view1_frontal.jpg
#   inflating: train/patient60637/study1/view1_frontal.jpg
#   inflating: train/patient60637/study1/view2_frontal.jpg
#   inflating: train/patient60638/study1/view1_frontal.jpg
#   inflating: train/patient60638/study2/view1_frontal.jpg
#   inflating: train/patient60638/study3/view1_frontal.jpg
#   inflating: train/patient60638/study3/view2_lateral.jpg
#   inflating: train/patient60639/study1/view1_frontal.jpg
#   inflating: train/patient60639/study1/view2_frontal.jpg
#   inflating: train/patient60639/study1/view3_lateral.jpg
#   inflating: train/patient60640/study1/view1_frontal.jpg
#   inflating: train/patient60640/study1/view2_lateral.jpg
#   inflating: train/patient60641/study1/view1_frontal.jpg
#   inflating: train/patient60641/study1/view2_lateral.jpg
#   inflating: train/patient60642/study1/view1_frontal.jpg
#   inflating: train/patient60642/study1/view2_lateral.jpg
#   inflating: train/patient60643/study1/view1_frontal.jpg
#   inflating: train/patient60644/study1/view1_frontal.jpg
#   inflating: train/patient60644/study1/view2_frontal.jpg
#   inflating: train/patient60645/study1/view1_frontal.jpg
#   inflating: train/patient60645/study1/view2_lateral.jpg
#   inflating: train/patient60645/study1/view3_lateral.jpg
#   inflating: train/patient60646/study1/view1_frontal.jpg
#   inflating: train/patient60647/study1/view1_frontal.jpg
#   inflating: train/patient60647/study1/view2_frontal.jpg
#   inflating: train/patient60647/study2/view1_frontal.jpg
#   inflating: train/patient60648/study1/view1_frontal.jpg
#   inflating: train/patient60648/study1/view2_lateral.jpg
#   inflating: train/patient60649/study1/view1_frontal.jpg
#   inflating: train/patient60649/study1/view2_lateral.jpg
#   inflating: train/patient60650/study1/view1_frontal.jpg
#   inflating: train/patient60650/study1/view2_lateral.jpg
#   inflating: train/patient60651/study1/view1_frontal.jpg
#   inflating: train/patient60651/study2/view1_frontal.jpg
#   inflating: train/patient60652/study1/view1_frontal.jpg
#   inflating: train/patient60652/study1/view2_lateral.jpg
#   inflating: train/patient60653/study1/view1_frontal.jpg
#   inflating: train/patient60653/study1/view2_lateral.jpg
#   inflating: train/patient60654/study1/view1_frontal.jpg
#   inflating: train/patient60654/study1/view2_lateral.jpg
#   inflating: train/patient60655/study1/view1_frontal.jpg
#   inflating: train/patient60655/study1/view2_frontal.jpg
#   inflating: train/patient60656/study1/view1_frontal.jpg
#   inflating: train/patient60656/study2/view1_frontal.jpg
#   inflating: train/patient60656/study2/view2_lateral.jpg
#   inflating: train/patient60656/study3/view1_frontal.jpg
#   inflating: train/patient60656/study4/view1_frontal.jpg
#   inflating: train/patient60657/study1/view1_frontal.jpg
#   inflating: train/patient60657/study2/view1_frontal.jpg
#   inflating: train/patient60657/study2/view2_lateral.jpg
#   inflating: train/patient60658/study1/view1_frontal.jpg
#   inflating: train/patient60658/study1/view2_frontal.jpg
#   inflating: train/patient60658/study1/view3_lateral.jpg
#   inflating: train/patient60659/study1/view1_frontal.jpg
#   inflating: train/patient60659/study1/view2_lateral.jpg
#   inflating: train/patient60660/study1/view1_frontal.jpg
#   inflating: train/patient60660/study1/view2_lateral.jpg
#   inflating: train/patient60661/study1/view1_frontal.jpg
#   inflating: train/patient60661/study1/view2_frontal.jpg
#   inflating: train/patient60662/study1/view1_frontal.jpg
#   inflating: train/patient60662/study1/view2_lateral.jpg
#   inflating: train/patient60663/study1/view1_frontal.jpg
#   inflating: train/patient60663/study1/view2_lateral.jpg
#   inflating: train/patient60664/study1/view1_frontal.jpg
#   inflating: train/patient60664/study1/view2_lateral.jpg
#   inflating: train/patient60665/study1/view1_frontal.jpg
#   inflating: train/patient60665/study1/view2_frontal.jpg
#   inflating: train/patient60666/study1/view1_frontal.jpg
#   inflating: train/patient60666/study1/view2_lateral.jpg
#   inflating: train/patient60667/study1/view1_frontal.jpg
#   inflating: train/patient60667/study1/view2_lateral.jpg
#   inflating: train/patient60668/study1/view1_frontal.jpg
#   inflating: train/patient60668/study1/view2_lateral.jpg
#   inflating: train/patient60669/study1/view1_frontal.jpg
#   inflating: train/patient60669/study1/view2_lateral.jpg
#   inflating: train/patient60670/study1/view1_frontal.jpg
#   inflating: train/patient60670/study1/view2_lateral.jpg
#   inflating: train/patient60671/study1/view1_frontal.jpg
#   inflating: train/patient60671/study1/view2_lateral.jpg
#   inflating: train/patient60672/study1/view1_frontal.jpg
#   inflating: train/patient60672/study1/view2_lateral.jpg
#   inflating: train/patient60673/study1/view1_frontal.jpg
#   inflating: train/patient60673/study1/view2_frontal.jpg
#   inflating: train/patient60674/study1/view1_frontal.jpg
#   inflating: train/patient60674/study1/view2_lateral.jpg
#   inflating: train/patient60674/study2/view1_frontal.jpg
#   inflating: train/patient60675/study1/view1_frontal.jpg
#   inflating: train/patient60675/study1/view2_lateral.jpg
#   inflating: train/patient60676/study1/view1_frontal.jpg
#   inflating: train/patient60676/study1/view2_lateral.jpg
#   inflating: train/patient60677/study1/view1_frontal.jpg
#   inflating: train/patient60677/study1/view2_lateral.jpg
#   inflating: train/patient60678/study1/view1_frontal.jpg
#   inflating: train/patient60678/study1/view2_lateral.jpg
#   inflating: train/patient60679/study1/view1_frontal.jpg
#   inflating: train/patient60679/study1/view2_lateral.jpg
#   inflating: train/patient60679/study2/view1_frontal.jpg
#   inflating: train/patient60680/study1/view1_frontal.jpg
#   inflating: train/patient60681/study1/view1_frontal.jpg
#   inflating: train/patient60681/study1/view2_lateral.jpg
#   inflating: train/patient60682/study1/view1_frontal.jpg
#   inflating: train/patient60682/study1/view2_lateral.jpg
#   inflating: train/patient60683/study1/view1_frontal.jpg
#   inflating: train/patient60683/study1/view2_frontal.jpg
#   inflating: train/patient60684/study1/view1_frontal.jpg
#   inflating: train/patient60684/study1/view2_lateral.jpg
#   inflating: train/patient60685/study1/view1_frontal.jpg
#   inflating: train/patient60685/study1/view2_lateral.jpg
#   inflating: train/patient60685/study1/view3_lateral.jpg
#   inflating: train/patient60686/study1/view1_frontal.jpg
#   inflating: train/patient60686/study1/view2_lateral.jpg
#   inflating: train/patient60687/study1/view1_frontal.jpg
#   inflating: train/patient60687/study1/view2_lateral.jpg
#   inflating: train/patient60688/study1/view1_frontal.jpg
#   inflating: train/patient60688/study1/view2_frontal.jpg
#   inflating: train/patient60689/study1/view1_frontal.jpg
#   inflating: train/patient60689/study2/view1_frontal.jpg
#   inflating: train/patient60690/study1/view1_frontal.jpg
#   inflating: train/patient60690/study1/view2_lateral.jpg
#   inflating: train/patient60691/study1/view1_frontal.jpg
#   inflating: train/patient60692/study1/view1_frontal.jpg
#   inflating: train/patient60692/study1/view2_lateral.jpg
#   inflating: train/patient60693/study1/view1_frontal.jpg
#   inflating: train/patient60693/study1/view2_lateral.jpg
#   inflating: train/patient60694/study1/view1_frontal.jpg
#   inflating: train/patient60695/study1/view1_frontal.jpg
#   inflating: train/patient60695/study1/view2_lateral.jpg
#   inflating: train/patient60695/study1/view3_lateral.jpg
#   inflating: train/patient60696/study1/view1_frontal.jpg
#   inflating: train/patient60696/study2/view1_frontal.jpg
#   inflating: train/patient60697/study1/view1_frontal.jpg
#   inflating: train/patient60698/study1/view1_frontal.jpg
#   inflating: train/patient60698/study1/view2_lateral.jpg
#   inflating: train/patient60699/study1/view1_frontal.jpg
#   inflating: train/patient60699/study1/view2_lateral.jpg
#   inflating: train/patient60700/study1/view1_frontal.jpg
#   inflating: train/patient60701/study1/view1_frontal.jpg
#   inflating: train/patient60701/study2/view1_frontal.jpg
#   inflating: train/patient60701/study2/view2_lateral.jpg
#   inflating: train/patient60702/study1/view1_frontal.jpg
#   inflating: train/patient60702/study1/view2_lateral.jpg
#   inflating: train/patient60703/study1/view1_frontal.jpg
#   inflating: train/patient60703/study1/view2_lateral.jpg
#   inflating: train/patient60704/study1/view1_frontal.jpg
#   inflating: train/patient60704/study1/view2_lateral.jpg
#   inflating: train/patient60704/study1/view3_lateral.jpg
#   inflating: train/patient60705/study1/view1_frontal.jpg
#   inflating: train/patient60706/study1/view1_frontal.jpg
#   inflating: train/patient60706/study1/view2_lateral.jpg
#   inflating: train/patient60707/study1/view1_frontal.jpg
#   inflating: train/patient60707/study1/view2_lateral.jpg
#   inflating: train/patient60708/study1/view1_frontal.jpg
#   inflating: train/patient60708/study1/view2_lateral.jpg
#   inflating: train/patient60709/study1/view1_frontal.jpg
#   inflating: train/patient60710/study1/view1_frontal.jpg
#   inflating: train/patient60711/study1/view1_frontal.jpg
#   inflating: train/patient60711/study1/view2_frontal.jpg
#   inflating: train/patient60712/study1/view1_frontal.jpg
#   inflating: train/patient60712/study2/view1_frontal.jpg
#   inflating: train/patient60713/study1/view1_frontal.jpg
#   inflating: train/patient60714/study1/view1_frontal.jpg
#   inflating: train/patient60715/study1/view1_frontal.jpg
#   inflating: train/patient60716/study1/view1_frontal.jpg
#   inflating: train/patient60717/study1/view1_frontal.jpg
#   inflating: train/patient60718/study1/view1_frontal.jpg
#   inflating: train/patient60719/study1/view1_frontal.jpg
#   inflating: train/patient60720/study1/view1_frontal.jpg
#   inflating: train/patient60721/study1/view1_frontal.jpg
#   inflating: train/patient60722/study1/view1_frontal.jpg
#   inflating: train/patient60722/study2/view1_frontal.jpg
#   inflating: train/patient60723/study1/view1_frontal.jpg
#   inflating: train/patient60724/study1/view1_frontal.jpg
#   inflating: train/patient60725/study1/view1_frontal.jpg
#   inflating: train/patient60726/study1/view1_frontal.jpg
#   inflating: train/patient60727/study1/view1_frontal.jpg
#   inflating: train/patient60728/study1/view1_frontal.jpg
#   inflating: train/patient60729/study1/view1_frontal.jpg
#   inflating: train/patient60730/study1/view1_frontal.jpg
#   inflating: train/patient60731/study1/view1_frontal.jpg
#   inflating: train/patient60732/study1/view1_frontal.jpg
#   inflating: train/patient60733/study1/view1_frontal.jpg
#   inflating: train/patient60734/study1/view1_frontal.jpg
#   inflating: train/patient60735/study1/view1_frontal.jpg
#   inflating: train/patient60736/study1/view1_frontal.jpg
#   inflating: train/patient60737/study1/view1_frontal.jpg
#   inflating: train/patient60738/study1/view1_frontal.jpg
#   inflating: train/patient60739/study1/view1_frontal.jpg
#   inflating: train/patient60740/study1/view1_frontal.jpg
#   inflating: train/patient60741/study1/view1_frontal.jpg
#   inflating: train/patient60742/study1/view1_frontal.jpg
#   inflating: train/patient60742/study2/view1_frontal.jpg
#   inflating: train/patient60743/study1/view1_frontal.jpg
#   inflating: train/patient60744/study1/view1_frontal.jpg
#   inflating: train/patient60745/study1/view1_frontal.jpg
#   inflating: train/patient60746/study1/view1_frontal.jpg
#   inflating: train/patient60747/study1/view1_frontal.jpg
#   inflating: train/patient60747/study2/view1_frontal.jpg
#   inflating: train/patient60748/study1/view1_frontal.jpg
#   inflating: train/patient60749/study1/view1_frontal.jpg
#   inflating: train/patient60750/study1/view1_frontal.jpg
#   inflating: train/patient60751/study1/view1_frontal.jpg
#   inflating: train/patient60752/study1/view1_frontal.jpg
#   inflating: train/patient60753/study1/view1_frontal.jpg
#   inflating: train/patient60753/study2/view1_frontal.jpg
#   inflating: train/patient60754/study1/view1_frontal.jpg
#   inflating: train/patient60755/study1/view1_frontal.jpg
#   inflating: train/patient60756/study1/view1_frontal.jpg
#   inflating: train/patient60756/study2/view1_frontal.jpg
#   inflating: train/patient60757/study1/view1_frontal.jpg
#   inflating: train/patient60757/study2/view1_frontal.jpg
#   inflating: train/patient60758/study1/view1_frontal.jpg
#   inflating: train/patient60759/study1/view1_frontal.jpg
#   inflating: train/patient60760/study1/view1_frontal.jpg
#   inflating: train/patient60761/study1/view1_frontal.jpg
#   inflating: train/patient60762/study1/view1_frontal.jpg
#   inflating: train/patient60763/study1/view1_frontal.jpg
#   inflating: train/patient60764/study1/view1_frontal.jpg
#   inflating: train/patient60765/study1/view1_frontal.jpg
#   inflating: train/patient60766/study1/view1_frontal.jpg
#   inflating: train/patient60767/study1/view1_frontal.jpg
#   inflating: train/patient60768/study1/view1_frontal.jpg
#   inflating: train/patient60769/study1/view1_frontal.jpg
#   inflating: train/patient60770/study1/view1_frontal.jpg
#   inflating: train/patient60771/study1/view1_frontal.jpg
#   inflating: train/patient60772/study1/view1_frontal.jpg
#   inflating: train/patient60773/study1/view1_frontal.jpg
#   inflating: train/patient60774/study1/view1_frontal.jpg
#   inflating: train/patient60775/study1/view1_frontal.jpg
#   inflating: train/patient60775/study2/view1_frontal.jpg
#   inflating: train/patient60776/study1/view1_frontal.jpg
#   inflating: train/patient60777/study1/view1_frontal.jpg
#   inflating: train/patient60778/study1/view1_frontal.jpg
#   inflating: train/patient60779/study1/view1_frontal.jpg
#   inflating: train/patient60780/study1/view1_frontal.jpg
#   inflating: train/patient60781/study1/view1_frontal.jpg
#   inflating: train/patient60782/study1/view1_frontal.jpg
#   inflating: train/patient60783/study1/view1_frontal.jpg
#   inflating: train/patient60784/study1/view1_frontal.jpg
#   inflating: train/patient60785/study1/view1_frontal.jpg
#   inflating: train/patient60786/study1/view1_frontal.jpg
#   inflating: train/patient60787/study1/view1_frontal.jpg
#   inflating: train/patient60788/study1/view1_frontal.jpg
#   inflating: train/patient60789/study1/view1_frontal.jpg
#   inflating: train/patient60790/study1/view1_frontal.jpg
#   inflating: train/patient60791/study1/view1_frontal.jpg
#   inflating: train/patient60792/study1/view1_frontal.jpg
#   inflating: train/patient60792/study2/view1_frontal.jpg
#   inflating: train/patient60793/study1/view1_frontal.jpg
#   inflating: train/patient60794/study1/view1_frontal.jpg
#   inflating: train/patient60795/study1/view1_frontal.jpg
#   inflating: train/patient60796/study1/view1_frontal.jpg
#   inflating: train/patient60797/study1/view1_frontal.jpg
#   inflating: train/patient60797/study2/view1_frontal.jpg
#   inflating: train/patient60798/study1/view1_frontal.jpg
#   inflating: train/patient60799/study1/view1_frontal.jpg
#   inflating: train/patient60800/study1/view1_frontal.jpg
#   inflating: train/patient60801/study1/view1_frontal.jpg
#   inflating: train/patient60802/study1/view1_frontal.jpg
#   inflating: train/patient60803/study1/view1_frontal.jpg
#   inflating: train/patient60804/study1/view1_frontal.jpg
#   inflating: train/patient60805/study1/view1_frontal.jpg
#   inflating: train/patient60806/study1/view1_frontal.jpg
#   inflating: train/patient60807/study1/view1_frontal.jpg
#   inflating: train/patient60808/study1/view1_frontal.jpg
#   inflating: train/patient60809/study1/view1_frontal.jpg
#   inflating: train/patient60810/study1/view1_frontal.jpg
#   inflating: train/patient60811/study1/view1_frontal.jpg
#   inflating: train/patient60811/study2/view1_frontal.jpg
#   inflating: train/patient60811/study3/view1_frontal.jpg
#   inflating: train/patient60812/study1/view1_frontal.jpg
#   inflating: train/patient60813/study1/view1_frontal.jpg
#   inflating: train/patient60814/study1/view1_frontal.jpg
#   inflating: train/patient60815/study1/view1_frontal.jpg
#   inflating: train/patient60816/study1/view1_frontal.jpg
#   inflating: train/patient60817/study1/view1_frontal.jpg
#   inflating: train/patient60818/study1/view1_frontal.jpg
#   inflating: train/patient60819/study1/view1_frontal.jpg
#   inflating: train/patient60820/study1/view1_frontal.jpg
#   inflating: train/patient60821/study1/view1_frontal.jpg
#   inflating: train/patient60822/study1/view1_frontal.jpg
#   inflating: train/patient60823/study1/view1_frontal.jpg
#   inflating: train/patient60824/study1/view1_frontal.jpg
#   inflating: train/patient60824/study2/view1_frontal.jpg
#   inflating: train/patient60825/study1/view1_frontal.jpg
#   inflating: train/patient60826/study1/view1_frontal.jpg
#   inflating: train/patient60827/study1/view1_frontal.jpg
#   inflating: train/patient60827/study2/view1_frontal.jpg
#   inflating: train/patient60828/study1/view1_frontal.jpg
#   inflating: train/patient60829/study1/view1_frontal.jpg
#   inflating: train/patient60830/study1/view1_frontal.jpg
#   inflating: train/patient60831/study1/view1_frontal.jpg
#   inflating: train/patient60832/study1/view1_frontal.jpg
#   inflating: train/patient60833/study1/view1_frontal.jpg
#   inflating: train/patient60834/study1/view1_frontal.jpg
#   inflating: train/patient60835/study1/view1_frontal.jpg
#   inflating: train/patient60836/study1/view1_frontal.jpg
#   inflating: train/patient60837/study1/view1_frontal.jpg
#   inflating: train/patient60838/study1/view1_frontal.jpg
#   inflating: train/patient60838/study2/view1_frontal.jpg
#   inflating: train/patient60839/study1/view1_frontal.jpg
#   inflating: train/patient60840/study1/view1_frontal.jpg
#   inflating: train/patient60841/study1/view1_frontal.jpg
#   inflating: train/patient60842/study1/view1_frontal.jpg
#   inflating: train/patient60843/study1/view1_frontal.jpg
#   inflating: train/patient60844/study1/view1_frontal.jpg
#   inflating: train/patient60844/study2/view1_frontal.jpg
#   inflating: train/patient60845/study1/view1_frontal.jpg
#   inflating: train/patient60846/study1/view1_frontal.jpg
#   inflating: train/patient60847/study1/view1_frontal.jpg
#   inflating: train/patient60848/study1/view1_frontal.jpg
#   inflating: train/patient60849/study1/view1_frontal.jpg
#   inflating: train/patient60850/study1/view1_frontal.jpg
#   inflating: train/patient60851/study1/view1_frontal.jpg
#   inflating: train/patient60852/study1/view1_frontal.jpg
#   inflating: train/patient60853/study1/view1_frontal.jpg
#   inflating: train/patient60854/study1/view1_frontal.jpg
#   inflating: train/patient60855/study1/view1_frontal.jpg
#   inflating: train/patient60856/study1/view1_frontal.jpg
#   inflating: train/patient60857/study1/view1_frontal.jpg
#   inflating: train/patient60858/study1/view1_frontal.jpg
#   inflating: train/patient60859/study1/view1_frontal.jpg
#   inflating: train/patient60860/study1/view1_frontal.jpg
#   inflating: train/patient60861/study1/view1_frontal.jpg
#   inflating: train/patient60861/study2/view1_frontal.jpg
#   inflating: train/patient60861/study3/view1_frontal.jpg
#   inflating: train/patient60861/study4/view1_frontal.jpg
#   inflating: train/patient60862/study1/view1_frontal.jpg
#   inflating: train/patient60863/study1/view1_frontal.jpg
#   inflating: train/patient60864/study1/view1_frontal.jpg
#   inflating: train/patient60865/study1/view1_frontal.jpg
#   inflating: train/patient60866/study1/view1_frontal.jpg
#   inflating: train/patient60867/study1/view1_frontal.jpg
#   inflating: train/patient60868/study1/view1_frontal.jpg
#   inflating: train/patient60869/study1/view1_frontal.jpg
#   inflating: train/patient60870/study1/view1_frontal.jpg
#   inflating: train/patient60870/study2/view1_frontal.jpg
#   inflating: train/patient60871/study1/view1_frontal.jpg
#   inflating: train/patient60872/study1/view1_frontal.jpg
#   inflating: train/patient60873/study1/view1_frontal.jpg
#   inflating: train/patient60874/study1/view1_frontal.jpg
#   inflating: train/patient60875/study1/view1_frontal.jpg
#   inflating: train/patient60876/study1/view1_frontal.jpg
#   inflating: train/patient60877/study1/view1_frontal.jpg
#   inflating: train/patient60878/study1/view1_frontal.jpg
#   inflating: train/patient60879/study1/view1_frontal.jpg
#   inflating: train/patient60880/study1/view1_frontal.jpg
#   inflating: train/patient60881/study1/view1_frontal.jpg
#   inflating: train/patient60882/study1/view1_frontal.jpg
#   inflating: train/patient60883/study1/view1_frontal.jpg
#   inflating: train/patient60884/study1/view1_frontal.jpg
#   inflating: train/patient60885/study1/view1_frontal.jpg
#   inflating: train/patient60886/study1/view1_frontal.jpg
#   inflating: train/patient60887/study1/view1_frontal.jpg
#   inflating: train/patient60887/study2/view1_frontal.jpg
#   inflating: train/patient60888/study1/view1_frontal.jpg
#   inflating: train/patient60889/study1/view1_frontal.jpg
#   inflating: train/patient60890/study1/view1_frontal.jpg
#   inflating: train/patient60891/study1/view1_frontal.jpg
#   inflating: train/patient60892/study1/view1_frontal.jpg
#   inflating: train/patient60893/study1/view1_frontal.jpg
#   inflating: train/patient60894/study1/view1_frontal.jpg
#   inflating: train/patient60895/study1/view1_frontal.jpg
#   inflating: train/patient60896/study1/view1_frontal.jpg
#   inflating: train/patient60897/study1/view1_frontal.jpg
#   inflating: train/patient60898/study1/view1_frontal.jpg
#   inflating: train/patient60899/study1/view1_frontal.jpg
#   inflating: train/patient60900/study1/view1_frontal.jpg
#   inflating: train/patient60901/study1/view1_frontal.jpg
#   inflating: train/patient60902/study1/view1_frontal.jpg
#   inflating: train/patient60902/study2/view1_frontal.jpg
#   inflating: train/patient60903/study1/view1_frontal.jpg
#   inflating: train/patient60904/study1/view1_frontal.jpg
#   inflating: train/patient60904/study2/view1_frontal.jpg
#   inflating: train/patient60905/study1/view1_frontal.jpg
#   inflating: train/patient60906/study1/view1_frontal.jpg
#   inflating: train/patient60907/study1/view1_frontal.jpg
#   inflating: train/patient60908/study1/view1_frontal.jpg
#   inflating: train/patient60909/study1/view1_frontal.jpg
#   inflating: train/patient60910/study1/view1_frontal.jpg
#   inflating: train/patient60911/study1/view1_frontal.jpg
#   inflating: train/patient60912/study1/view1_frontal.jpg
#   inflating: train/patient60913/study1/view1_frontal.jpg
#   inflating: train/patient60914/study1/view1_frontal.jpg
#   inflating: train/patient60915/study1/view1_frontal.jpg
#   inflating: train/patient60916/study1/view1_frontal.jpg
#   inflating: train/patient60917/study1/view1_frontal.jpg
#   inflating: train/patient60918/study1/view1_frontal.jpg
#   inflating: train/patient60919/study1/view1_frontal.jpg
#   inflating: train/patient60920/study1/view1_frontal.jpg
#   inflating: train/patient60921/study1/view1_frontal.jpg
#   inflating: train/patient60922/study1/view1_frontal.jpg
#   inflating: train/patient60923/study1/view1_frontal.jpg
#   inflating: train/patient60924/study1/view1_frontal.jpg
#   inflating: train/patient60924/study2/view1_frontal.jpg
#   inflating: train/patient60925/study1/view1_frontal.jpg
#   inflating: train/patient60926/study1/view1_frontal.jpg
#   inflating: train/patient60927/study1/view1_frontal.jpg
#   inflating: train/patient60927/study2/view1_frontal.jpg
#   inflating: train/patient60928/study1/view1_frontal.jpg
#   inflating: train/patient60929/study1/view1_frontal.jpg
#   inflating: train/patient60930/study1/view1_frontal.jpg
#   inflating: train/patient60931/study1/view1_frontal.jpg
#   inflating: train/patient60932/study1/view1_frontal.jpg
#   inflating: train/patient60933/study1/view1_frontal.jpg
#   inflating: train/patient60933/study2/view1_frontal.jpg
#   inflating: train/patient60934/study1/view1_frontal.jpg
#   inflating: train/patient60935/study1/view1_frontal.jpg
#   inflating: train/patient60936/study1/view1_frontal.jpg
#   inflating: train/patient60937/study1/view1_frontal.jpg
#   inflating: train/patient60938/study1/view1_frontal.jpg
#   inflating: train/patient60939/study1/view1_frontal.jpg
#   inflating: train/patient60940/study1/view1_frontal.jpg
#   inflating: train/patient60941/study1/view1_frontal.jpg
#   inflating: train/patient60942/study1/view1_frontal.jpg
#   inflating: train/patient60943/study1/view1_frontal.jpg
#   inflating: train/patient60944/study1/view1_frontal.jpg
# ...
#   inflating: train/patient64509/study2/view1_frontal.jpg
#   inflating: train/patient64510/study1/view1_frontal.jpg
#   inflating: train/patient64511/study1/view1_frontal.jpg
#   inflating: train/patient64512/study1/view1_frontal.jpg
#   inflating: train/patient64513/study1/view1_frontal.jpg
#   inflating: train/patient64514/study1/view1_frontal.jpg
#   inflating: train/patient64515/study1/view1_frontal.jpg
#   inflating: train/patient64516/study1/view1_frontal.jpg
#   inflating: train/patient64517/study1/view1_frontal.jpg
#   inflating: train/patient64518/study1/view1_frontal.jpg
#   inflating: train/patient64519/study1/view1_frontal.jpg
#   inflating: train/patient64520/study1/view1_frontal.jpg
#   inflating: train/patient64521/study1/view1_frontal.jpg
#   inflating: train/patient64522/study1/view1_frontal.jpg
#   inflating: train/patient64523/study1/view1_frontal.jpg
#   inflating: train/patient64524/study1/view1_frontal.jpg
#   inflating: train/patient64525/study1/view1_frontal.jpg
#   inflating: train/patient64526/study1/view1_frontal.jpg
#   inflating: train/patient64527/study1/view1_frontal.jpg
#   inflating: train/patient64527/study2/view1_frontal.jpg
#   inflating: train/patient64528/study1/view1_frontal.jpg
#   inflating: train/patient64529/study1/view1_frontal.jpg
#   inflating: train/patient64530/study1/view1_frontal.jpg
#   inflating: train/patient64531/study1/view1_frontal.jpg
#   inflating: train/patient64532/study1/view1_frontal.jpg
#   inflating: train/patient64533/study1/view1_frontal.jpg
#   inflating: train/patient64533/study2/view1_frontal.jpg
#   inflating: train/patient64534/study1/view1_frontal.jpg
#   inflating: train/patient64535/study1/view1_frontal.jpg
#   inflating: train/patient64536/study1/view1_frontal.jpg
#   inflating: train/patient64536/study2/view1_frontal.jpg
#   inflating: train/patient64537/study1/view1_frontal.jpg
#   inflating: train/patient64537/study2/view1_frontal.jpg
#   inflating: train/patient64538/study1/view1_frontal.jpg
#   inflating: train/patient64539/study1/view1_frontal.jpg
#   inflating: train/patient64540/study1/view1_frontal.jpg
#   inflating: valid.csv
#   inflating: valid/patient64541/study1/view1_frontal.jpg
#   inflating: valid/patient64542/study1/view1_frontal.jpg
#   inflating: valid/patient64542/study1/view2_lateral.jpg
#   inflating: valid/patient64543/study1/view1_frontal.jpg
#   inflating: valid/patient64544/study1/view1_frontal.jpg
#   inflating: valid/patient64545/study1/view1_frontal.jpg
#   inflating: valid/patient64546/study1/view1_frontal.jpg
#   inflating: valid/patient64547/study1/view1_frontal.jpg
#   inflating: valid/patient64547/study1/view2_frontal.jpg
#   inflating: valid/patient64547/study1/view3_lateral.jpg
#   inflating: valid/patient64548/study1/view1_frontal.jpg
#   inflating: valid/patient64549/study1/view1_frontal.jpg
#   inflating: valid/patient64550/study1/view1_frontal.jpg
#   inflating: valid/patient64551/study1/view1_frontal.jpg
#   inflating: valid/patient64551/study1/view2_lateral.jpg
#   inflating: valid/patient64552/study1/view1_frontal.jpg
#   inflating: valid/patient64553/study1/view1_frontal.jpg
#   inflating: valid/patient64554/study1/view1_frontal.jpg
#   inflating: valid/patient64555/study1/view1_frontal.jpg
#   inflating: valid/patient64556/study1/view1_frontal.jpg
#   inflating: valid/patient64556/study1/view2_lateral.jpg
#   inflating: valid/patient64557/study1/view1_frontal.jpg
#   inflating: valid/patient64558/study1/view1_frontal.jpg
#   inflating: valid/patient64558/study1/view2_lateral.jpg
#   inflating: valid/patient64559/study1/view1_frontal.jpg
#   inflating: valid/patient64559/study1/view2_lateral.jpg
#   inflating: valid/patient64560/study1/view1_frontal.jpg
#   inflating: valid/patient64560/study1/view2_lateral.jpg
#   inflating: valid/patient64561/study1/view1_frontal.jpg
#   inflating: valid/patient64562/study1/view1_frontal.jpg
#   inflating: valid/patient64563/study1/view1_frontal.jpg
#   inflating: valid/patient64564/study1/view1_frontal.jpg
#   inflating: valid/patient64565/study1/view1_frontal.jpg
#   inflating: valid/patient64566/study1/view1_frontal.jpg
#   inflating: valid/patient64566/study1/view2_lateral.jpg
#   inflating: valid/patient64567/study1/view1_frontal.jpg
#   inflating: valid/patient64567/study1/view2_lateral.jpg
#   inflating: valid/patient64568/study1/view1_frontal.jpg
#   inflating: valid/patient64569/study1/view1_frontal.jpg
#   inflating: valid/patient64570/study1/view1_frontal.jpg
#   inflating: valid/patient64570/study1/view2_lateral.jpg
#   inflating: valid/patient64571/study1/view1_frontal.jpg
#   inflating: valid/patient64572/study1/view1_frontal.jpg
#   inflating: valid/patient64573/study1/view1_frontal.jpg
#   inflating: valid/patient64574/study1/view1_frontal.jpg
#   inflating: valid/patient64575/study1/view1_frontal.jpg
#   inflating: valid/patient64575/study1/view2_lateral.jpg
#   inflating: valid/patient64576/study1/view1_frontal.jpg
#   inflating: valid/patient64577/study1/view1_frontal.jpg
#   inflating: valid/patient64578/study1/view1_frontal.jpg
#   inflating: valid/patient64579/study1/view1_frontal.jpg
#   inflating: valid/patient64580/study1/view1_frontal.jpg
#   inflating: valid/patient64581/study1/view1_frontal.jpg
#   inflating: valid/patient64581/study1/view2_frontal.jpg
#   inflating: valid/patient64581/study1/view3_lateral.jpg
#   inflating: valid/patient64582/study1/view1_frontal.jpg
#   inflating: valid/patient64583/study1/view1_frontal.jpg
#   inflating: valid/patient64584/study1/view1_frontal.jpg
#   inflating: valid/patient64584/study1/view2_lateral.jpg
#   inflating: valid/patient64585/study1/view1_frontal.jpg
#   inflating: valid/patient64586/study1/view1_frontal.jpg
#   inflating: valid/patient64587/study1/view1_frontal.jpg
#   inflating: valid/patient64588/study1/view1_frontal.jpg
#   inflating: valid/patient64588/study1/view2_lateral.jpg
#   inflating: valid/patient64589/study1/view1_frontal.jpg
#   inflating: valid/patient64589/study1/view2_lateral.jpg
#   inflating: valid/patient64590/study1/view1_frontal.jpg
#   inflating: valid/patient64590/study1/view2_lateral.jpg
#   inflating: valid/patient64591/study1/view1_frontal.jpg
#   inflating: valid/patient64592/study1/view1_frontal.jpg
#   inflating: valid/patient64593/study1/view1_frontal.jpg
#   inflating: valid/patient64594/study1/view1_frontal.jpg
#   inflating: valid/patient64594/study1/view2_lateral.jpg
#   inflating: valid/patient64595/study1/view1_frontal.jpg
#   inflating: valid/patient64595/study1/view2_lateral.jpg
#   inflating: valid/patient64596/study1/view1_frontal.jpg
#   inflating: valid/patient64597/study1/view1_frontal.jpg
#   inflating: valid/patient64597/study1/view2_lateral.jpg
#   inflating: valid/patient64598/study1/view1_frontal.jpg
#   inflating: valid/patient64599/study1/view1_frontal.jpg
#   inflating: valid/patient64599/study1/view2_lateral.jpg
#   inflating: valid/patient64600/study1/view1_frontal.jpg
#   inflating: valid/patient64600/study1/view2_lateral.jpg
#   inflating: valid/patient64601/study1/view1_frontal.jpg
#   inflating: valid/patient64602/study1/view1_frontal.jpg
#   inflating: valid/patient64603/study1/view1_frontal.jpg
#   inflating: valid/patient64604/study1/view1_frontal.jpg
#   inflating: valid/patient64605/study1/view1_frontal.jpg
#   inflating: valid/patient64606/study1/view1_frontal.jpg
#   inflating: valid/patient64606/study1/view2_lateral.jpg
#   inflating: valid/patient64607/study1/view1_frontal.jpg
#   inflating: valid/patient64608/study1/view1_frontal.jpg
#   inflating: valid/patient64608/study1/view2_lateral.jpg
#   inflating: valid/patient64609/study1/view1_frontal.jpg
#   inflating: valid/patient64610/study1/view1_frontal.jpg
#   inflating: valid/patient64611/study1/view1_frontal.jpg
#   inflating: valid/patient64612/study1/view1_frontal.jpg
#   inflating: valid/patient64613/study1/view1_frontal.jpg
#   inflating: valid/patient64613/study1/view2_lateral.jpg
#   inflating: valid/patient64614/study1/view1_frontal.jpg
#   inflating: valid/patient64615/study1/view1_frontal.jpg
#   inflating: valid/patient64615/study1/view2_lateral.jpg
#   inflating: valid/patient64616/study1/view1_frontal.jpg
#   inflating: valid/patient64616/study1/view2_lateral.jpg
#   inflating: valid/patient64616/study1/view3_lateral.jpg
#   inflating: valid/patient64617/study1/view1_frontal.jpg
#   inflating: valid/patient64618/study1/view1_frontal.jpg
#   inflating: valid/patient64618/study1/view2_lateral.jpg
#   inflating: valid/patient64619/study1/view1_frontal.jpg
#   inflating: valid/patient64620/study1/view1_frontal.jpg
#   inflating: valid/patient64621/study1/view1_frontal.jpg
#   inflating: valid/patient64622/study1/view1_frontal.jpg
#   inflating: valid/patient64623/study1/view1_frontal.jpg
#   inflating: valid/patient64624/study1/view1_frontal.jpg
#   inflating: valid/patient64625/study1/view1_frontal.jpg
#   inflating: valid/patient64625/study1/view2_lateral.jpg
#   inflating: valid/patient64626/study1/view1_frontal.jpg
#   inflating: valid/patient64627/study1/view1_frontal.jpg
#   inflating: valid/patient64628/study1/view1_frontal.jpg
#   inflating: valid/patient64629/study1/view1_frontal.jpg
#   inflating: valid/patient64630/study1/view1_frontal.jpg
#   inflating: valid/patient64631/study1/view1_frontal.jpg
#   inflating: valid/patient64632/study1/view1_frontal.jpg
#   inflating: valid/patient64633/study1/view1_frontal.jpg
#   inflating: valid/patient64634/study1/view1_frontal.jpg
#   inflating: valid/patient64635/study1/view1_frontal.jpg
#   inflating: valid/patient64636/study1/view1_frontal.jpg
#   inflating: valid/patient64637/study1/view1_frontal.jpg
#   inflating: valid/patient64638/study1/view1_frontal.jpg
#   inflating: valid/patient64639/study1/view1_frontal.jpg
#   inflating: valid/patient64640/study1/view1_frontal.jpg
#   inflating: valid/patient64640/study1/view2_lateral.jpg
#   inflating: valid/patient64641/study1/view1_frontal.jpg
#   inflating: valid/patient64642/study1/view1_frontal.jpg
#   inflating: valid/patient64643/study1/view1_frontal.jpg
#   inflating: valid/patient64644/study1/view1_frontal.jpg
#   inflating: valid/patient64645/study1/view1_frontal.jpg
#   inflating: valid/patient64646/study1/view1_frontal.jpg
#   inflating: valid/patient64647/study1/view1_frontal.jpg
#   inflating: valid/patient64648/study1/view1_frontal.jpg
#   inflating: valid/patient64649/study1/view1_frontal.jpg
#   inflating: valid/patient64650/study1/view1_frontal.jpg
#   inflating: valid/patient64651/study1/view1_frontal.jpg
#   inflating: valid/patient64652/study1/view1_frontal.jpg
#   inflating: valid/patient64653/study1/view1_frontal.jpg
#   inflating: valid/patient64654/study1/view1_frontal.jpg
#   inflating: valid/patient64655/study1/view1_frontal.jpg
#   inflating: valid/patient64656/study1/view1_frontal.jpg
#   inflating: valid/patient64657/study1/view1_frontal.jpg
#   inflating: valid/patient64658/study1/view1_frontal.jpg
#   inflating: valid/patient64659/study1/view1_frontal.jpg
#   inflating: valid/patient64660/study1/view1_frontal.jpg
#   inflating: valid/patient64661/study1/view1_frontal.jpg
#   inflating: valid/patient64662/study1/view1_frontal.jpg
#   inflating: valid/patient64663/study1/view1_frontal.jpg
#   inflating: valid/patient64664/study1/view1_frontal.jpg
#   inflating: valid/patient64665/study1/view1_frontal.jpg
#   inflating: valid/patient64666/study1/view1_frontal.jpg
#   inflating: valid/patient64667/study1/view1_frontal.jpg
#   inflating: valid/patient64668/study1/view1_frontal.jpg
#   inflating: valid/patient64669/study1/view1_frontal.jpg
#   inflating: valid/patient64670/study1/view1_frontal.jpg
#   inflating: valid/patient64671/study1/view1_frontal.jpg
#   inflating: valid/patient64672/study1/view1_frontal.jpg
#   inflating: valid/patient64673/study1/view1_frontal.jpg
#   inflating: valid/patient64674/study1/view1_frontal.jpg
#   inflating: valid/patient64675/study1/view1_frontal.jpg
#   inflating: valid/patient64676/study1/view1_frontal.jpg
#   inflating: valid/patient64676/study1/view2_lateral.jpg
#   inflating: valid/patient64677/study1/view1_frontal.jpg
#   inflating: valid/patient64678/study1/view1_frontal.jpg
#   inflating: valid/patient64679/study1/view1_frontal.jpg
#   inflating: valid/patient64680/study1/view1_frontal.jpg
#   inflating: valid/patient64681/study1/view1_frontal.jpg
#   inflating: valid/patient64682/study1/view1_frontal.jpg
#   inflating: valid/patient64683/study1/view1_frontal.jpg
#   inflating: valid/patient64684/study1/view1_frontal.jpg
#   inflating: valid/patient64685/study1/view1_frontal.jpg
#   inflating: valid/patient64686/study1/view1_frontal.jpg
#   inflating: valid/patient64687/study1/view1_frontal.jpg
#   inflating: valid/patient64688/study1/view1_frontal.jpg
#   inflating: valid/patient64689/study1/view1_frontal.jpg
#   inflating: valid/patient64690/study1/view1_frontal.jpg
#   inflating: valid/patient64691/study1/view1_frontal.jpg
#   inflating: valid/patient64692/study1/view1_frontal.jpg
#   inflating: valid/patient64693/study1/view1_frontal.jpg
#   inflating: valid/patient64694/study1/view1_frontal.jpg
#   inflating: valid/patient64695/study1/view1_frontal.jpg
#   inflating: valid/patient64696/study1/view1_frontal.jpg
#   inflating: valid/patient64697/study1/view1_frontal.jpg
#   inflating: valid/patient64698/study1/view1_frontal.jpg
#   inflating: valid/patient64699/study1/view1_frontal.jpg
#   inflating: valid/patient64700/study1/view1_frontal.jpg
#   inflating: valid/patient64701/study1/view1_frontal.jpg
#   inflating: valid/patient64702/study1/view1_frontal.jpg
#   inflating: valid/patient64703/study1/view1_frontal.jpg
#   inflating: valid/patient64704/study1/view1_frontal.jpg
#   inflating: valid/patient64705/study1/view1_frontal.jpg
#   inflating: valid/patient64705/study1/view2_lateral.jpg
#   inflating: valid/patient64706/study1/view1_frontal.jpg
#   inflating: valid/patient64707/study1/view1_frontal.jpg
#   inflating: valid/patient64708/study1/view1_frontal.jpg
#   inflating: valid/patient64709/study1/view1_frontal.jpg
#   inflating: valid/patient64710/study1/view1_frontal.jpg
#   inflating: valid/patient64711/study1/view1_frontal.jpg
#   inflating: valid/patient64712/study1/view1_frontal.jpg
#   inflating: valid/patient64713/study1/view1_frontal.jpg
#   inflating: valid/patient64714/study1/view1_frontal.jpg
#   inflating: valid/patient64715/study1/view1_frontal.jpg
#   inflating: valid/patient64716/study1/view1_frontal.jpg
#   inflating: valid/patient64717/study1/view1_frontal.jpg
#   inflating: valid/patient64718/study1/view1_frontal.jpg
#   inflating: valid/patient64719/study1/view1_frontal.jpg
#   inflating: valid/patient64720/study1/view1_frontal.jpg
#   inflating: valid/patient64721/study1/view1_frontal.jpg
#   inflating: valid/patient64722/study1/view1_frontal.jpg
#   inflating: valid/patient64723/study1/view1_frontal.jpg
#   inflating: valid/patient64724/study1/view1_frontal.jpg
#   inflating: valid/patient64725/study1/view1_frontal.jpg
#   inflating: valid/patient64726/study1/view1_frontal.jpg
#   inflating: valid/patient64727/study1/view1_frontal.jpg
#   inflating: valid/patient64728/study1/view1_frontal.jpg
#   inflating: valid/patient64729/study1/view1_frontal.jpg
#   inflating: valid/patient64730/study1/view1_frontal.jpg
#   inflating: valid/patient64731/study1/view1_frontal.jpg
#   inflating: valid/patient64732/study1/view1_frontal.jpg
#   inflating: valid/patient64733/study1/view1_frontal.jpg
#   inflating: valid/patient64734/study1/view1_frontal.jpg
#   inflating: valid/patient64735/study1/view1_frontal.jpg
#   inflating: valid/patient64736/study1/view1_frontal.jpg
#   inflating: valid/patient64737/study1/view1_frontal.jpg
#   inflating: valid/patient64738/study1/view1_frontal.jpg
#   inflating: valid/patient64739/study1/view1_frontal.jpg
#   inflating: valid/patient64740/study1/view1_frontal.jpg

# %%
# %ls CheXpert-v1.0-small
# Out:
# train/  train.csv  valid/  valid.csv

# %%
import numpy as np
import pandas as pd
import time
import csv
import random
import matplotlib.pyplot as plt
from PIL import Image
# !pip install barbar
from barbar import Bar

import torch
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.data.dataset import random_split

import sklearn.metrics as metrics
from sklearn.metrics import roc_auc_score

use_gpu = torch.cuda.is_available()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting barbar
#   Downloading barbar-0.2.1-py3-none-any.whl (3.9 kB)
# Installing collected packages: barbar
# Successfully installed barbar-0.2.1

# %%
print(use_gpu)
# Out:
# True

# %%
import csv
class CheXpertDataSet(Dataset):
    def __init__(self, data_PATH, transform = None, policy = "ones"):
        """
        data_PATH: path to the file containing images with corresponding labels.
        transform: optional transform to be applied on a sample.
        Upolicy: name the policy with regard to the uncertain labels.
        """
        image_names = []
        labels = []

        with open(data_PATH, "r") as f:
            csvReader = csv.reader(f)
            next(csvReader, None) # skip the header
            for line in csvReader:
                image_name = line[0]
                label = line[5:]
                
                for i in range(14):
                    if label[i]:
                        a = float(label[i])
                        if a == 1:
                            label[i] = 1
                        elif a == -1:
                            if policy == "ones":
                                label[i] = 1
                            elif policy == "zeroes":
                                label[i] = 0
                            else:
                                label[i] = 0
                        else:
                            label[i] = 0
                    else:
                        label[i] = 0
                        
                image_names.append('./' + image_name)
                labels.append(label)

        self.image_names = image_names
        self.labels = labels
        self.transform = transform

    def __getitem__(self, index):
        """Take the index of item and returns the image and its labels"""
        image_name = self.image_names[index]
        image = Image.open(image_name).convert('RGB')
        label = self.labels[index]
        if self.transform is not None:
            image = self.transform(image)
        return image, torch.FloatTensor(label)

    def __len__(self):
        return len(self.image_names)

# %%
# %ls
# Out:
# CheXpert-v1.0-small.zip  train_old/  train_old.csv

# %%
# %mkdir CheXpert-v1.0-small
# %mv train CheXpert-v1.0-small
# %mv train.csv CheXpert-v1.0-small
# %mv valid.csv CheXpert-v1.0-small
# %mv valid CheXpert-v1.0-small
# %ls
# Out:
# CheXpert-v1.0-small/  CheXpert-v1.0-small.zip  train_old/  train_old.csv

# %%
# Paths to the files with training, and validation sets.
# Each file contains pairs (path to image, output vector)
Traindata = pd.read_csv('./CheXpert-v1.0-small/train.csv')
Traindata = Traindata[Traindata['Path'].str.contains("frontal")] # use only frontal images
Traindata = Traindata[500:]
Traindata.to_csv('./CheXpert-v1.0-small/train_mod.csv', index = False)
print("Train data length:", len(Traindata))

Validdata = pd.read_csv('./CheXpert-v1.0-small/valid.csv')
Validdata = Validdata[Validdata['Path'].str.contains("frontal")] # use only frontal images
Validdata.to_csv('./CheXpert-v1.0-small/valid_mod.csv', index = False)
print("Valid data length:", len(Validdata))

#Testdata = Traindata.head(500) # use first 500 training data as test data (obs ratio is almost same!)
#Testdata.to_csv('./CheXpert-v1.0-small/test_mod.csv', index = False)
#print("Test data length:", len(Testdata))

pathFileTrain = './CheXpert-v1.0-small/train_mod.csv'
pathFileValid = './CheXpert-v1.0-small/valid_mod.csv'
#pathFileTest = './CheXpert-v1.0-small/test_mod.csv'

# Neural network parameters:
nnIsTrained = False     # pre-trained using ImageNet
nnClassCount = 14       # dimension of the output

# Training settings: batch size, maximum number of epochs
trBatchSize = 16
trMaxEpoch = 3

# Parameters related to image transforms: size of the down-scaled image, cropped image
imgtransResize = (320, 320)
imgtransCrop = 224

# Class names
class_names = ['No Finding', 'Enlarged Cardiomediastinum', 'Cardiomegaly', 'Lung Opacity', 
               'Lung Lesion', 'Edema', 'Consolidation', 'Pneumonia', 'Atelectasis', 'Pneumothorax', 
               'Pleural Effusion', 'Pleural Other', 'Fracture', 'Support Devices']
# Out:
# Train data length: 190527
# Valid data length: 202

# %%
IMAGENET_MEAN = [0.485, 0.456, 0.406]  # mean of ImageNet dataset(for normalization)
IMAGENET_STD = [0.229, 0.224, 0.225]   # std of ImageNet dataset(for normalization)

# Tranform data
normalize = transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD)
transformList = []

transformList.append(transforms.Resize((imgtransCrop, imgtransCrop))) # 224
# transformList.append(transforms.RandomResizedCrop(imgtransCrop))
# transformList.append(transforms.RandomHorizontalFlip())
transformList.append(transforms.ToTensor())
# transformList.append(normalize)
transformSequence = transforms.Compose(transformList)

# Load dataset
datasetTrain = CheXpertDataSet(pathFileTrain, transformSequence, policy = "zeros")
print("Train data length:", len(datasetTrain))

datasetValid = CheXpertDataSet(pathFileValid, transformSequence)
print("Valid data length:", len(datasetValid))

#datasetTest = CheXpertDataSet(pathFileTest, transformSequence, policy = "ones")
#print("Test data length:", len(datasetTest))
# Out:
# Train data length: 190527
# Valid data length: 202

# %%
class DenseNet121(nn.Module):
    """Model modified.
    The architecture of our model is the same as standard DenseNet121
    except the classifier layer which has an additional sigmoid function.
    """
    def __init__(self, out_size):
        super(DenseNet121, self).__init__()
        self.densenet121 = torchvision.models.densenet121(pretrained = False)
        num_ftrs = self.densenet121.classifier.in_features
        self.densenet121.classifier = nn.Sequential(
            nn.Linear(num_ftrs, out_size),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.densenet121(x)
        return x

# %%
# %mkdir saved_models
# %ls
# Out:
# CheXpert-v1.0-small/     saved_models/  train_old.csv
# CheXpert-v1.0-small.zip  train_old/

# %%
class CheXpertTrainer():

    def train(model, dataLoaderTrain, dataLoaderVal, nnClassCount, trMaxEpoch, checkpoint):
        optimizer = optim.Adam(model.parameters(), lr = 0.0001, # setting optimizer & scheduler
                               betas = (0.9, 0.999), eps = 1e-08, weight_decay = 0) 
        loss = torch.nn.BCELoss() # setting loss function
        
        if checkpoint != None and use_gpu: # loading checkpoint
            modelCheckpoint = torch.load(checkpoint)
            model.load_state_dict(modelCheckpoint['state_dict'])
            optimizer.load_state_dict(modelCheckpoint['optimizer'])
            
        # Train the network
        lossMIN = 100000
        train_start = []
        train_end = []
        for epochID in range(0, trMaxEpoch):
            train_start.append(time.time()) # training starts
            losst = CheXpertTrainer.epochTrain(model, dataLoaderTrain, optimizer, trMaxEpoch, nnClassCount, loss)
            train_end.append(time.time()) # training ends
            lossv = CheXpertTrainer.epochVal(model, dataLoaderVal, optimizer, trMaxEpoch, nnClassCount, loss)
            print("Training loss: {:.3f},".format(losst), "Valid loss: {:.3f}".format(lossv))
            
            if lossv < lossMIN:
                lossMIN = lossv
                torch.save({'epoch': epochID + 1, 'state_dict': model.state_dict(), 
                            'best_loss': lossMIN, 'optimizer' : optimizer.state_dict()}, 
                           'm-epoch_FL' + str(epochID + 1) + '.pth.tar')
                print('Epoch ' + str(epochID + 1) + ' [save] loss = ' + str(lossv))
            else:
                print('Epoch ' + str(epochID + 1) + ' [----] loss = ' + str(lossv))

            torch.save(model, './saved_models/train.pt')

        train_time = np.array(train_end) - np.array(train_start)
        print("Training time for each epoch: {} seconds".format(train_time.round(0)))
        params = model.state_dict()
        return params
       
        
    def epochTrain(model, dataLoaderTrain, optimizer, epochMax, classCount, loss):
        losstrain = 0
        model.train()

        for batchID, (varInput, target) in enumerate(Bar(dataLoaderTrain)):
            
            varTarget = target.cuda(non_blocking = True)
            varOutput = model(varInput)
            lossvalue = loss(varOutput, target)
                       
            optimizer.zero_grad()
            lossvalue.backward()
            optimizer.step()
            
            losstrain += lossvalue.item()
            
        return losstrain / len(dataLoaderTrain)
    
    
    def epochVal(model, dataLoaderVal, optimizer, epochMax, classCount, loss):
        model.eval()
        lossVal = 0

        with torch.no_grad():
            for i, (varInput, target) in enumerate(dataLoaderVal):
                
                target = target.cuda(non_blocking = True)
                varOutput = model(varInput)
                
                lossVal += loss(varOutput, target)
                
        return lossVal / len(dataLoaderVal)

    
    def computeAUROC(dataGT, dataPRED, classCount):
        # Computes area under ROC curve 
        # dataGT: ground truth data
        # dataPRED: predicted data
        outAUROC = []
        datanpGT = dataGT.cpu().numpy()
        datanpPRED = dataPRED.cpu().numpy()
        
        for i in range(classCount):
            try:
                outAUROC.append(roc_auc_score(datanpGT[:, i], datanpPRED[:, i]))
            except ValueError:
                pass
        return outAUROC
    
    
    def test(model, dataLoaderTest, nnClassCount, checkpoint, class_names):
        cudnn.benchmark = True
        
        if checkpoint != None and use_gpu:
            modelCheckpoint = torch.load(checkpoint)
            model.load_state_dict(modelCheckpoint['state_dict'])

        if use_gpu:
            outGT = torch.FloatTensor().cuda()
            outPRED = torch.FloatTensor().cuda()
        else:
            outGT = torch.FloatTensor()
            outPRED = torch.FloatTensor()
       
        model.eval()
        
        with torch.no_grad():
            for i, (input, target) in enumerate(dataLoaderTest):

                target = target.cuda()
                outGT = torch.cat((outGT, target), 0).cuda()

                bs, c, h, w = input.size()
                varInput = input.view(-1, c, h, w)
            
                out = model(varInput)
                outPRED = torch.cat((outPRED, out), 0)
        aurocIndividual = CheXpertTrainer.computeAUROC(outGT, outPRED, nnClassCount)
        aurocMean = np.array(aurocIndividual).mean()
        print('AUROC mean ', aurocMean)
        
        for i in range (0, len(aurocIndividual)):
            print(class_names[i], ' ', aurocIndividual[i])
        
        return outGT, outPRED

# %%
epoch = 3
batch = 72
trBatchSize = 16
model = DenseNet121(nnClassCount)
dataLoaderVal = DataLoader(dataset = datasetValid, batch_size = trBatchSize, 
                           shuffle = False, num_workers = 2, pin_memory = True)
dataLoaderTrain = DataLoader(dataset = datasetTrain, batch_size = trBatchSize,
                               shuffle = True, num_workers = 2, pin_memory = True)

CheXpertTrainer.train(model, dataLoaderTrain, dataLoaderVal, # Step 3: Perform local computations
                                          nnClassCount, trMaxEpoch = epoch, checkpoint = None)
# Out:
#   1936/190527: [>...............................] - ETA 103520.8s
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-068dc397ea2b> in <cell line: 10>()
#       8                                shuffle = True, num_workers = 2, pin_memory = True)
#       9
# ---> 10 CheXpertTrainer.train(model, dataLoaderTrain, dataLoaderVal, # Step 3: Perform local computations
#      11                                           nnClassCount, trMaxEpoch = epoch, checkpoint = None)
#
# <ipython-input-25-c4c9fc776b5a> in train(model, dataLoaderTrain, dataLoaderVal, nnClassCount, trMaxEpoch, checkpoint)
#      17         for epochID in range(0, trMaxEpoch):
#      18             train_start.append(time.time()) # training starts
# ---> 19             losst = CheXpertTrainer.epochTrain(model, dataLoaderTrain, optimizer, trMaxEpoch, nnClassCount, loss)
#      20             train_end.append(time.time()) # training ends
#      21             lossv = CheXpertTrainer.epochVal(model, dataLoaderVal, optimizer, trMaxEpoch, nnClassCount, loss)
#
# <ipython-input-25-c4c9fc776b5a> in epochTrain(model, dataLoaderTrain, optimizer, epochMax, classCount, loss)
#      43         model.train()
#      44
# ---> 45         for batchID, (varInput, target) in enumerate(Bar(dataLoaderTrain)):
#      46
#      47             varTarget = target.cuda(non_blocking = True)
#
# /usr/local/lib/python3.10/dist-packages/barbar/Bar.py in __next__(self)
#      33
#      34         try:
# ---> 35             batch = next(self.iterator)
#      36             self._display()
#      37         except StopIteration:
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     631                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632                 self._reset()  # type: ignore[call-arg]
# --> 633             data = self._next_data()
#     634             self._num_yielded += 1
#     635             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1343             else:
#    1344                 del self._task_info[idx]
# -> 1345                 return self._process_data(data)
#    1346
#    1347     def _try_put_index(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#    1369         self._try_put_index()
#    1370         if isinstance(data, ExceptionWrapper):
# -> 1371             data.reraise()
#    1372         return data
#    1373
#
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py in reraise(self)
#     642             # instantiate since we don't know how to
#     643             raise RuntimeError(msg) from None
# --> 644         raise exception
#     645
#     646
#
# FileNotFoundError: Caught FileNotFoundError in DataLoader worker process 1.
# Original Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/worker.py", line 308, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "<ipython-input-18-eadfc4e41038>", line 46, in __getitem__
#     image = Image.open(image_name).convert('RGB')
#   File "/usr/local/lib/python3.10/dist-packages/PIL/Image.py", line 2975, in open
#     fp = builtins.open(filename, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: './CheXpert-v1.0-small/train/patient00237/study2/view1_frontal.jpg'

# %%
drive.flush_and_unmount()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-35-7e7fc67cc157>", line 1, in <cell line: 1>
#     drive.flush_and_unmount()
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/drive.py", line 98, in flush_and_unmount
#     raise ValueError('flush_and_unmount failed')
# ValueError: flush_and_unmount failed
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-35-7e7fc67cc157>", line 1, in <cell line: 1>
#     drive.flush_and_unmount()
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/drive.py", line 98, in flush_and_unmount
#     raise ValueError('flush_and_unmount failed')
# ValueError: flush_and_unmount failed
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-35-7e7fc67cc157>", line 1, in <cell line: 1>
#     drive.flush_and_unmount()
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/drive.py", line 98, in flush_and_unmount
#     raise ValueError('flush_and_unmount failed')
# ValueError: flush_and_unmount failed
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
# FOR MULTIPLE COMMUNICATION ROUNDS
com_round = 3
fraction = 1.0
epoch = 3
batch = 48
num_clients = 5

'''
# Divide datasetTrain_ex
datasetTrain_1, datasetTrain_2, datasetTrain_3, datasetTrain_4, datasetTrain_5, dataleft = random_split(datasetTrain, 
                                                                                                        [100, 100, 100, 100, 100,
                                                                                                         len(datasetTrain) - 500])
'''
# Divide datasetTrain_real
datasetTrain_1, datasetTrain_2, datasetTrain_3, datasetTrain_4, datasetTrain_5 = random_split(datasetTrain, 
                                                                                              [38106, 38106, 38105, 38105, 38105])


# Define 5 DataLoaders
dataLoaderTrain_1 = DataLoader(dataset = datasetTrain_1, batch_size = trBatchSize,
                               shuffle = True, num_workers = 2, pin_memory = True)
dataLoaderTrain_2 = DataLoader(dataset = datasetTrain_2, batch_size = trBatchSize,
                               shuffle = True, num_workers = 2, pin_memory = True)
dataLoaderTrain_3 = DataLoader(dataset = datasetTrain_3, batch_size = trBatchSize,
                               shuffle = True, num_workers = 2, pin_memory = True)
dataLoaderTrain_4 = DataLoader(dataset = datasetTrain_4, batch_size = trBatchSize,
                               shuffle = True, num_workers = 2, pin_memory = True)
dataLoaderTrain_5 = DataLoader(dataset = datasetTrain_5, batch_size = trBatchSize,
                               shuffle = True, num_workers = 2, pin_memory = True)

# Define Valid and Test DataLoaders
dataLoaderVal = DataLoader(dataset = datasetValid, batch_size = trBatchSize, 
                           shuffle = False, num_workers = 2, pin_memory = True)
dataLoaderTest = DataLoader(dataset = datasetTest, num_workers = 2, pin_memory = True)

# %%
dT = [datasetTrain_1, datasetTrain_2, datasetTrain_3, datasetTrain_4, datasetTrain_5]
dLT = [dataLoaderTrain_1, dataLoaderTrain_2, dataLoaderTrain_3, dataLoaderTrain_4, dataLoaderTrain_5]

model = DenseNet121(nnClassCount).cuda() # Step 0: Initialize global model and load the model
model = torch.nn.DataParallel(model).cuda()

for i in range(com_round):
    print("[[[ Round {} Start ]]]".format(i + 1))
    params = [None] * num_clients
    sel_clients = sorted(random.sample(range(num_clients), 
                                       round(num_clients*fraction))) # Step 1: select random fraction of clients
    print("The number of clients:", len(sel_clients))
    for j in sel_clients: # Step 2: send weights to clients
        print("<< Client {} Training Start >>".format(j + 1))
        train_valid_start = time.time()
        params[j] = CheXpertTrainer.train(model, dLT[j], dataLoaderVal, # Step 3: Perform local computations
                                          nnClassCount, trMaxEpoch = epoch, checkpoint = None)
        train_valid_end = time.time()
        client_time = round(train_valid_end - train_valid_start)
        print("<< Client {} Training End: {} seconds elapsed >>".format(j + 1, client_time))
        
    fidx = [idx for idx in range(len(params)) if params[idx] != None][0]
    lidx = [idx for idx in range(len(params)) if params[idx] != None][-1]
    for key in params[fidx]: # Step 4: return updates to server
        weights, weightn = [], []
        for k in sel_clients:
            weights.append(params[k][key]*len(dT[k]))
            weightn.append(len(dT[k]))
        params[lidx][key] = sum(weights) / sum(weightn) # weighted averaging model weights

    model = DenseNet121(nnClassCount).cuda()
    model = torch.nn.DataParallel(model).cuda()
    model.load_state_dict(params[lidx]) # Step 5: server updates global state
    print("[[[ Round {} End ]]]".format(i + 1))
    
print("Global model trained")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define your model
class MyModel(nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()
        # Define your model architecture here

    def forward(self, x):
        # Define the forward pass of your model here
        pass

# Define hyperparameters
num_epochs = 10
batch_size = 32
learning_rate = 0.001

# Define data transformations
data_transforms = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize the input images to a fixed size
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize the image data
])

# Load the dataset
train_dataset = ImageFolder("path/to/train/folder", transform=data_transforms)
val_dataset = ImageFolder("path/to/validation/folder", transform=data_transforms)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Initialize the model
model = MyModel().to(device)

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Training loop
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Print training progress
        if (i + 1) % 100 == 0:
            print(f"Epoch [{epoch + 1}/{num_epochs}], Step [{i + 1}/{total_step}], Loss: {loss.item():.4f}")

# Save the trained model
torch.save(model.state_dict(), "path/to/save/model.pth")

# %%
drive.flush_and_unmount()
